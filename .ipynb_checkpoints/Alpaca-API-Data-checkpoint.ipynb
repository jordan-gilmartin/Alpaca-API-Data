# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv

# %matplotlib inline

# %%
# Load .env enviroment variables
load_dotenv('api_keys.env')
# Out:
# True

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# %%
# Import alpaca-py as alpaca
from alpaca.data.historical import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoLatestQuoteRequest, CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame
from datetime import datetime

# %%
# Declaring variable for client
client = CryptoHistoricalDataClient()

# %%
# Setting up params for request
request_params = CryptoLatestQuoteRequest(symbol_or_symbols="BTC/USD")

# %%
# Grabbing latest price with client
latest_quote = client.get_crypto_latest_quote(request_params)

# %%
# must use symbol to access even though it is single symbol
latest_quote["BTC/USD"].ask_price
# Out:
# 23123.88

# %%
# Updating params for historical price data
request_params = CryptoBarsRequest(
                        symbol_or_symbols=["BTC/USD"],
                        timeframe=TimeFrame.Day,
                        start=datetime.strptime("2020-04-01", '%Y-%m-%d')
                        )

# %%
# Grabbing historical data
bars = client.get_crypto_bars(request_params)

# %%
# convert to dataframe
bars.df
# Out:
#                                        open      high       low     close  \
# symbol  timestamp
# BTC/USD 2020-04-08 05:00:00+00:00   7314.00   7314.00   7314.00   7314.00
#         2020-04-14 05:00:00+00:00   7101.50   7101.50   7100.00   7100.00
#         2020-04-22 05:00:00+00:00   7118.50   7118.50   7118.50   7118.50
#         2020-04-28 05:00:00+00:00   7748.50   7836.00   7748.50   7836.00
#         2020-04-30 05:00:00+00:00   8829.00   8829.00   8653.00   8653.00
# ...                                     ...       ...       ...       ...
#         2023-01-22 06:00:00+00:00  22867.27  23068.00  22290.04  22715.61
#         2023-01-23 06:00:00+00:00  22719.69  23164.32  22436.55  23113.10
#         2023-01-24 06:00:00+00:00  23110.16  23148.86  22299.00  22674.10
#         2023-01-25 06:00:00+00:00  22671.72  23815.12  22340.48  23147.84
#         2023-01-26 06:00:00+00:00  23149.46  23246.84  22863.04  23119.72
#
#                                         volume  trade_count          vwap
# symbol  timestamp
# BTC/USD 2020-04-08 05:00:00+00:00     0.000100          1.0   7314.000000
#         2020-04-14 05:00:00+00:00     0.000200          2.0   7100.750000
#         2020-04-22 05:00:00+00:00     0.000100          1.0   7118.500000
#         2020-04-28 05:00:00+00:00     0.084000          2.0   7835.687500
#         2020-04-30 05:00:00+00:00     0.013400          3.0   8715.805970
# ...                                        ...          ...           ...
#         2023-01-22 06:00:00+00:00  5341.862401     114588.0  22726.773982
#         2023-01-23 06:00:00+00:00  5717.197549     129258.0  22902.078791
#         2023-01-24 06:00:00+00:00  6133.996123     146290.0  22804.564391
#         2023-01-25 06:00:00+00:00  7437.157163     161470.0  22886.978420
#         2023-01-26 06:00:00+00:00  2847.755513      75851.0  23031.205110
#
# [994 rows x 7 columns]

# %%
# Setting as dataframe variable
btc_df = bars.df
btc_df
# Out:
#                                        open      high       low     close  \
# symbol  timestamp
# BTC/USD 2020-04-08 05:00:00+00:00   7314.00   7314.00   7314.00   7314.00
#         2020-04-14 05:00:00+00:00   7101.50   7101.50   7100.00   7100.00
#         2020-04-22 05:00:00+00:00   7118.50   7118.50   7118.50   7118.50
# 4     8653.00     0.013400          3.0   8715.805970
# ..        ...          ...          ...           ...
# 989  22715.61  5341.862401     114588.0  22726.773982
# 990  23113.10  5717.197549     129258.0  22902.078791
# 991  22674.10  6133.996123     146290.0  22804.564391
# 992  23147.84  7437.157163     161470.0  22886.978420
# 993  23119.72  2847.755513      75851.0  23031.205110
#
# [994 rows x 9 columns]

# %%
# Revising time out of timestamp column
import datetime as dt
btc_df['timestamp'] = btc_df['timestamp'].dt.date
btc_df
# Out:
#       symbol   timestamp      open      high       low     close       volume  \
# 0    BTC/USD  2020-04-08   7314.00   7314.00   7314.00   7314.00     0.000100
# 1    BTC/USD  2020-04-14   7101.50   7101.50   7100.00   7100.00     0.000200
# 2    BTC/USD  2020-04-22   7118.50   7118.50   7118.50   7118.50     0.000100
# 3    BTC/USD  2020-04-28   7748.50   7836.00   7748.50   7836.00     0.084000
# 4    BTC/USD  2020-04-30   8829.00   8829.00   8653.00   8653.00     0.013400
# ..       ...         ...       ...       ...       ...       ...          ...
# 989  BTC/USD  2023-01-22  22867.27  23068.00  22290.04  22715.61  5341.862401
# 990  BTC/USD  2023-01-23  22719.69  23164.32  22436.55  23113.10  5717.197549
# 991  BTC/USD  2023-01-24  23110.16  23148.86  22299.00  22674.10  6133.996123
# 992  BTC/USD  2023-01-25  22671.72  23815.12  22340.48  23147.84  7437.157163
# 993  BTC/USD  2023-01-26  23149.46  23246.84  22863.04  23119.72  2847.755513
#
#      trade_count          vwap
# 0            1.0   7314.000000
# 1            2.0   7100.750000
# 2            1.0   7118.500000
# 3            2.0   7835.687500
# 4            3.0   8715.805970
# ..           ...           ...
# 989     114588.0  22726.773982
# 990     129258.0  22902.078791
# 991     146290.0  22804.564391
# 992     161470.0  22886.978420
# 993      75851.0  23031.205110
#
# [994 rows x 9 columns]

# %%
# Setting up pivot to get subset of closing prices
btc_pivot = btc_df.pivot_table(values='close', index='timestamp', columns='symbol')
btc_pivot
# Out:
# symbol       BTC/USD
# timestamp
# 2020-04-08   7314.00
# 2020-04-14   7100.00
# 2020-04-22   7118.50
# 2020-04-28   7836.00
# 2020-04-30   8653.00
# ...              ...
# 2023-01-22  22715.61
# 2023-01-23  23113.10
# 2023-01-24  22674.10
# 2023-01-25  23147.84
# 2023-01-26  23119.72
#
# [994 rows x 1 columns]

# %%
# Checking for nulls
btc_pivot.isnull().sum()
# Out:
# symbol
# BTC/USD    0
# dtype: int64

# %%
# Running percentage change calculation and conversion
btc_daily = btc_pivot.pct_change()
btc_daily
# Out:
# symbol       BTC/USD
# timestamp
# 2020-04-08       NaN
# 2020-04-14 -0.029259
# 2020-04-22  0.002606
# 2020-04-28  0.100794
# 2020-04-30  0.104262
# ...              ...
# 2023-01-22 -0.006833
# 2023-01-23  0.017499
# 2023-01-24 -0.018994
# 2023-01-25  0.020893
# 2023-01-26 -0.001215
#
# [994 rows x 1 columns]

# %%
# Recheck nulls
btc_daily.isnull().sum()
# Out:
# symbol
# BTC/USD    1
# dtype: int64

# %%
# Drop nulls
btc_daily = btc_daily.dropna()
btc_daily
# Out:
# symbol       BTC/USD
# timestamp
# 2020-04-14 -0.029259
# 2020-04-22  0.002606
# 2020-04-28  0.100794
# 2020-04-30  0.104262
# 2020-05-01  0.018895
# ...              ...
# 2023-01-22 -0.006833
# 2023-01-23  0.017499
# 2023-01-24 -0.018994
# 2023-01-25  0.020893
# 2023-01-26 -0.001215
#
# [993 rows x 1 columns]

# %%
# Checking info
btc_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 993 entries, 2020-04-14 to 2023-01-26
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BTC/USD  993 non-null    float64
# dtypes: float64(1)
# memory usage: 15.5+ KB

# %%
# Setting up dependencies for stock price data
from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest

# %%
# keys required for stock historical data client
stock_client = StockHistoricalDataClient(alpaca_api_key, alpaca_secret_key)

# %%
# params request for multiple tickers
multisymbol_request_params = StockBarsRequest(symbol_or_symbols=["SPY", "GLD", "TLT"],
                                              timeframe=TimeFrame.Day, 
                                              start=datetime.strptime("2020-04-08", '%Y-%m-%d')
                                             )

# %%
# pulling data
historical_quotes = stock_client.get_stock_bars(multisymbol_request_params)

# %%
# Display as dataframe
historical_quotes.df
# Out:
#                                     open     high       low    close  \
# symbol timestamp
# GLD    2020-04-08 04:00:00+00:00  155.91  155.940  154.5900  154.650
#        2020-04-09 04:00:00+00:00  158.08  159.080  157.2100  158.580
#        2020-04-13 04:00:00+00:00  159.17  162.380  158.6250  161.410
#        2020-04-14 04:00:00+00:00  162.73  164.420  161.7800  162.660
#        2020-04-15 04:00:00+00:00  161.80  162.540  160.8061  162.000
# ...                                  ...      ...       ...      ...
# TLT    2023-01-20 05:00:00+00:00  106.96  107.240  106.1100  106.200
#        2023-01-23 05:00:00+00:00  105.57  106.200  105.4900  105.700
#        2023-01-24 05:00:00+00:00  106.12  107.450  105.3900  107.220
#        2023-01-25 05:00:00+00:00  107.37  107.905  106.6400  107.480
#        2023-01-26 05:00:00+00:00  107.14  107.650  106.4900  106.955
#
#                                       volume  trade_count        vwap
# symbol timestamp
# GLD    2020-04-08 04:00:00+00:00   7600804.0      60704.0  155.233884
#        2020-04-09 04:00:00+00:00  18123039.0     140239.0  158.255634
#        2020-04-13 04:00:00+00:00  20549213.0     140401.0  160.906373
#        2020-04-14 04:00:00+00:00  17095086.0     146336.0  163.197557
#        2020-04-15 04:00:00+00:00  12141890.0      95518.0  161.749049
# ...                                      ...          ...         ...
# TLT    2023-01-20 05:00:00+00:00  22754067.0     117267.0  106.435165
#        2023-01-23 05:00:00+00:00  12962623.0      84782.0  105.755560
#        2023-01-24 05:00:00+00:00  16418921.0      94935.0  106.886722
#        2023-01-25 05:00:00+00:00  12193402.0      79988.0  107.311356
#        2023-01-26 05:00:00+00:00  12601315.0      77377.0  107.058084
#
# [2118 rows x 7 columns]

# %%
# Save as df variable
stock_df = historical_quotes.df
stock_df
# Out:
#                                     open     high       low    close  \
# symbol timestamp
# GLD    2020-04-08 04:00:00+00:00  155.91  155.940  154.5900  154.650
#        2020-04-09 04:00:00+00:00  158.08  159.080  157.2100  158.580
# 707     1171999.0  278.251697
# 708      752225.0  274.512847
# 709      761246.0  282.089774
# 710      711140.0  277.826041
# ...           ...         ...
# 1407     505915.0  392.598891
# 1408     568843.0  399.770552
# 1409     434698.0  399.936054
# 1410     583223.0  397.857328
# 1411     452449.0  402.248276
#
# [706 rows x 9 columns]

# %%
# Pivot for SPY
spy_pivot = loc_df.pivot_table(values='close', index='timestamp', columns='symbol')
spy_pivot
# Out:
# symbol         SPY
# timestamp
# 2020-04-08  274.00
# 2020-04-09  278.22
# 2020-04-13  275.63
# 2020-04-14  283.80
# 2020-04-15  277.75
# ...            ...
# 2023-01-20  395.88
# 2023-01-23  400.63
# 2023-01-24  400.20
# 2023-01-25  400.35
# 2023-01-26  403.94
#
# [706 rows x 1 columns]

# %%
# Checking info
spy_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 706 entries, 2020-04-08 to 2023-01-26
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SPY     706 non-null    float64
# dtypes: float64(1)
# memory usage: 11.0+ KB

# %%
# Running percentage change calculation and conversion
spy_daily = spy_pivot.pct_change()
spy_daily
# Out:
# symbol           SPY
# timestamp
# 2020-04-08       NaN
# 2020-04-09  0.015401
# 2020-04-13 -0.009309
# 2020-04-14  0.029641
# 2020-04-15 -0.021318
# ...              ...
# 2023-01-20  0.018629
# 2023-01-23  0.011999
# 2023-01-24 -0.001073
# 2023-01-25  0.000375
# 2023-01-26  0.008967
#
# [706 rows x 1 columns]

# %%
# Dropping nulls
spy_daily = spy_daily.dropna()
spy_daily
# Out:
# symbol           SPY
# timestamp
# 2020-04-09  0.015401
# 2020-04-13 -0.009309
# 2020-04-14  0.029641
# 2020-04-15 -0.021318
# 2020-04-16  0.004356
# ...              ...
# 2023-01-20  0.018629
# 2023-01-23  0.011999
# 2023-01-24 -0.001073
# 2023-01-25  0.000375
# 2023-01-26  0.008967
#
# [705 rows x 1 columns]

# %%
# Subset of GLD only
gld_df = stock_df.loc[(stock_df.symbol == 'GLD'), :]
gld_df
# Out:
#     symbol   timestamp     open     high       low   close      volume  \
# 0      GLD  2020-04-08  155.910  155.940  154.5900  154.65   7600804.0
# 1      GLD  2020-04-09  158.080  159.080  157.2100  158.58  18123039.0
# 2      GLD  2020-04-13  159.170  162.380  158.6250  161.41  20549213.0
# 3      GLD  2020-04-14  162.730  164.420  161.7800  162.66  17095086.0
# 4      GLD  2020-04-15  161.800  162.540  160.8061  162.00  12141890.0
# ..     ...         ...      ...      ...       ...     ...         ...
# 701    GLD  2023-01-20  179.060  179.660  178.6450  179.29   5754818.0
# 702    GLD  2023-01-23  178.350  179.690  177.7800  179.63   5266105.0
# 703    GLD  2023-01-24  179.560  180.320  178.3500  180.28   4606873.0
# 704    GLD  2023-01-25  179.350  181.220  179.2925  181.11   6925348.0
# 705    GLD  2023-01-26  180.146  180.265  178.4600  179.46   5314473.0
#
#      trade_count        vwap
# 0        60704.0  155.233884
# 1       140239.0  158.255634
# 2       140401.0  160.906373
# 3       146336.0  163.197557
# 4        95518.0  161.749049
# ..           ...         ...
# 701      39721.0  179.267363
# 702      38761.0  178.849988
# 703      36768.0  179.788049
# 704      42153.0  180.161757
# 705      40414.0  179.485660
#
# [706 rows x 9 columns]

# %%
# Pivot for GLD
gld_pivot = gld_df.pivot_table(values='close', index='timestamp', columns='symbol')
gld_pivot
# Out:
# symbol         GLD
# timestamp
# 2020-04-08  154.65
# 2020-04-09  158.58
# 2020-04-13  161.41
# 2020-04-14  162.66
# 2020-04-15  162.00
# ...            ...
# 2023-01-20  179.29
# 2023-01-23  179.63
# 2023-01-24  180.28
# 2023-01-25  181.11
# 2023-01-26  179.46
#
# [706 rows x 1 columns]

# %%
# Checking info
gld_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 706 entries, 2020-04-08 to 2023-01-26
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GLD     706 non-null    float64
# dtypes: float64(1)
# memory usage: 11.0+ KB

# %%
# Running percentage change calculation and conversion
gld_daily = gld_pivot.pct_change()
gld_daily
# Out:
# symbol           GLD
# timestamp
# 2020-04-08       NaN
# 2020-04-09  0.025412
# 2020-04-13  0.017846
# 2020-04-14  0.007744
# 2020-04-15 -0.004058
# ...              ...
# 2023-01-20 -0.003335
# 2023-01-23  0.001896
# 2023-01-24  0.003619
# 2023-01-25  0.004604
# 2023-01-26 -0.009110
#
# [706 rows x 1 columns]

# %%
# Dropping nulls
gld_daily = gld_daily.dropna()
gld_daily
# Out:
# symbol           GLD
# timestamp
# 2020-04-09  0.025412
# 2020-04-13  0.017846
# 2020-04-14  0.007744
# 2020-04-15 -0.004058
# 2020-04-16 -0.001790
# ...              ...
# 2023-01-20 -0.003335
# 2023-01-23  0.001896
# 2023-01-24  0.003619
# 2023-01-25  0.004604
# 2023-01-26 -0.009110
#
# [705 rows x 1 columns]

# %%
# Subset of TLT only
tlt_df = stock_df.loc[(stock_df.symbol == 'TLT'), :]
tlt_df
# Out:
#      symbol   timestamp    open     high     low    close      volume  \
# 1412    TLT  2020-04-08  165.11  166.190  164.13  165.090  10147077.0
# 1413    TLT  2020-04-09  164.28  165.790  163.78  165.390  14260806.0
# 1414    TLT  2020-04-13  164.75  165.710  163.88  163.880   8750297.0
# 1415    TLT  2020-04-14  163.84  164.740  163.48  163.840   9019531.0
# 1416    TLT  2020-04-15  166.80  168.600  166.74  168.180  10027752.0
# ...     ...         ...     ...      ...     ...      ...         ...
# 2113    TLT  2023-01-20  106.96  107.240  106.11  106.200  22754067.0
# 2114    TLT  2023-01-23  105.57  106.200  105.49  105.700  12962623.0
# 2115    TLT  2023-01-24  106.12  107.450  105.39  107.220  16418921.0
# 2116    TLT  2023-01-25  107.37  107.905  106.64  107.480  12193402.0
# 2117    TLT  2023-01-26  107.14  107.650  106.49  106.955  12601315.0
#
#       trade_count        vwap
# 1412      63686.0  165.217491
# 1413      82515.0  164.996594
# 1414      60771.0  164.679842
# 1415      62051.0  164.073826
# 1416      63827.0  167.874800
# ...           ...         ...
# 2113     117267.0  106.435165
# 2114      84782.0  105.755560
# 2115      94935.0  106.886722
# 2116      79988.0  107.311356
# 2117      77377.0  107.058084
#
# [706 rows x 9 columns]

# %%
# Pivot for TLT
tlt_pivot = tlt_df.pivot_table(values='close', index='timestamp', columns='symbol')
tlt_pivot
# Out:
# symbol          TLT
# timestamp
# 2020-04-08  165.090
# 2020-04-09  165.390
# 2020-04-13  163.880
# 2020-04-14  163.840
# 2020-04-15  168.180
# ...             ...
# 2023-01-20  106.200
# 2023-01-23  105.700
# 2023-01-24  107.220
# 2023-01-25  107.480
# 2023-01-26  106.955
#
# [706 rows x 1 columns]

# %%
# Checking info
tlt_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 706 entries, 2020-04-08 to 2023-01-26
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TLT     706 non-null    float64
# dtypes: float64(1)
# memory usage: 11.0+ KB

# %%
# Running percentage change calculation and conversion
tlt_daily = tlt_pivot.pct_change()
tlt_daily
# Out:
# symbol           TLT
# timestamp
# 2020-04-08       NaN
# 2020-04-09  0.001817
# 2020-04-13 -0.009130
# 2020-04-14 -0.000244
# 2020-04-15  0.026489
# ...              ...
# 2023-01-20 -0.016211
# 2023-01-23 -0.004708
# 2023-01-24  0.014380
# 2023-01-25  0.002425
# 2023-01-26 -0.004885
#
# [706 rows x 1 columns]

# %%
# Dropping nulls
tlt_daily = tlt_daily.dropna()
tlt_daily
# Out:
# symbol           TLT
# timestamp
# 2020-04-09  0.001817
# 2020-04-13 -0.009130
# 2020-04-14 -0.000244
# 2020-04-15  0.026489
# 2020-04-16  0.011357
# ...              ...
# 2023-01-20 -0.016211
# 2023-01-23 -0.004708
# 2023-01-24  0.014380
# 2023-01-25  0.002425
# 2023-01-26 -0.004885
#
# [705 rows x 1 columns]

# %%
# Running cumprod (cumulative product) function over BTC Daily Returns to calculate overall gain / loss
BTC_cumprod = (1 + btc_daily).cumprod()
BTC_prod_annotation = (BTC_cumprod.iloc[-1][0]*100).round().astype(int)
BTC_cumprod
# Out:
# symbol       BTC/USD
# timestamp
# 2020-04-14  0.970741
# 2020-04-22  0.973270
# 2020-04-28  1.071370
# 2020-04-30  1.183074
# 2020-05-01  1.205428
# ...              ...
# 2023-01-22  3.105771
# 2023-01-23  3.160118
# 2023-01-24  3.100096
# 2023-01-25  3.164867
# 2023-01-26  3.161023
#
# [993 rows x 1 columns]

# %%
# Running cumprod (cumulative product) function over SPY Daily Returns to calculate overall gain / loss
SPY_cumprod = (1 + spy_daily).cumprod()
SPY_prod_annotation = (SPY_cumprod.iloc[-1][0]*100).round().astype(int)
SPY_cumprod
# Out:
# symbol           SPY
# timestamp
# 2020-04-09  1.015401
# 2020-04-13  1.005949
# 2020-04-14  1.035766
# 2020-04-15  1.013686
# 2020-04-16  1.018102
# ...              ...
# 2023-01-20  1.444818
# 2023-01-23  1.462153
# 2023-01-24  1.460584
# 2023-01-25  1.461131
# 2023-01-26  1.474234
#
# [705 rows x 1 columns]

# %%
# Running cumprod (cumulative product) function over GLD Daily Returns to calculate overall gain / loss
GLD_cumprod = (1 + gld_daily).cumprod()
GLD_prod_annotation = (GLD_cumprod.iloc[-1][0]*100).round().astype(int)
GLD_cumprod
# Out:
# symbol           GLD
# timestamp
# 2020-04-09  1.025412
# 2020-04-13  1.043712
# 2020-04-14  1.051794
# 2020-04-15  1.047527
# 2020-04-16  1.045651
# ...              ...
# 2023-01-20  1.159328
# 2023-01-23  1.161526
# 2023-01-24  1.165729
# 2023-01-25  1.171096
# 2023-01-26  1.160427
#
# [705 rows x 1 columns]

# %%
# Running cumprod (cumulative product) function over TLT Daily Returns to calculate overall gain / loss
TLT_cumprod = (1 + tlt_daily).cumprod()
TLT_prod_annotation = (TLT_cumprod.iloc[-1][0]*100).round().astype(int)
TLT_cumprod
# Out:
# symbol           TLT
# timestamp
# 2020-04-09  1.001817
# 2020-04-13  0.992671
# 2020-04-14  0.992428
# 2020-04-15  1.018717
# 2020-04-16  1.030287
# ...              ...
# 2023-01-20  0.643285
# 2023-01-23  0.640257
# 2023-01-24  0.649464
# 2023-01-25  0.651039
# 2023-01-26  0.647859
#
# [705 rows x 1 columns]

# %%
# Running cumulative return against initial investment to obtain current market value of investment in BTC
initial_investment = 10000
btc_profit = initial_investment * BTC_cumprod
btc_annotation = btc_profit.iloc[-1][0].round().astype(int)
btc_profit
# Out:
# symbol           BTC/USD
# timestamp
# 2020-04-14   9707.410446
# 2020-04-22   9732.704403
# 2020-04-28  10713.699754
# 2020-04-30  11830.735576
# 2020-05-01  12054.279464
# ...                  ...
# 2023-01-22  31057.711239
# 2023-01-23  31601.175827
# 2023-01-24  31000.957069
# 2023-01-25  31648.673776
# 2023-01-26  31610.226962
#
# [993 rows x 1 columns]

# %%
# Plot performance and save to Images
import matplotlib.pyplot as plt
btc_profit.plot(figsize=(20,10), legend=True, title="BTC Cumulative Returns - April 2020 to Present");
plt.savefig("Images/BTCCumulativeReturns.png")

# %%
# Running cumulative return against initial investment to obtain current market value of investment in SPY
spy_profit = initial_investment * SPY_cumprod
spy_annotation = spy_profit.iloc[-1][0].round().astype(int)
spy_profit
# Out:
# symbol               SPY
# timestamp
# 2020-04-09  10154.014599
# 2020-04-13  10059.489051
# 2020-04-14  10357.664234
# 2020-04-15  10136.861314
# 2020-04-16  10181.021898
# ...                  ...
# 2023-01-20  14448.175182
# 2023-01-23  14621.532847
# 2023-01-24  14605.839416
# 2023-01-25  14611.313869
# 2023-01-26  14742.335766
#
# [705 rows x 1 columns]

# %%
# Plot performance and save to Images
spy_profit.plot(figsize=(20,10), legend=True, title="SPY Cumulative Returns - April 2020 to Present");
plt.savefig("Images/SPYCumulativeReturns.png")

# %%
# Running cumulative return against initial investment to obtain current market value of investment in GLD
gld_profit = initial_investment * GLD_cumprod
gld_annotation = gld_profit.iloc[-1][0].round().astype(int)
gld_profit
# Out:
# symbol               GLD
# timestamp
# 2020-04-09  10254.122211
# 2020-04-13  10437.116069
# 2020-04-14  10517.943744
# 2020-04-15  10475.266731
# 2020-04-16  10456.514711
# ...                  ...
# 2023-01-20  11593.275137
# 2023-01-23  11615.260265
# 2023-01-24  11657.290656
# 2023-01-25  11710.960233
# 2023-01-26  11604.267701
#
# [705 rows x 1 columns]

# %%
# Plot performance and save to Images
gld_profit.plot(figsize=(20,10), legend=True, title="GLD Cumulative Returns - April 2020 to Present");
plt.savefig("Images/GLDCumulativeReturns.png")

# %%
# Running cumulative return against initial investment to obtain current market value of investment in TLT
tlt_profit = initial_investment * TLT_cumprod
tlt_annotation = tlt_profit.iloc[-1][0].round().astype(int)
tlt_profit
# Out:
# symbol               TLT
# timestamp
# 2020-04-09  10018.171906
# 2020-04-13   9926.706645
# 2020-04-14   9924.283724
# 2020-04-15  10187.170634
# 2020-04-16  10302.865104
# ...                  ...
# 2023-01-20   6432.854806
# 2023-01-23   6402.568296
# 2023-01-24   6494.639288
# 2023-01-25   6510.388273
# 2023-01-26   6478.587437
#
# [705 rows x 1 columns]

# %%
# Plot performance and save to Images
tlt_profit.plot(figsize=(20,10), legend=True, title="TLT Cumulative Returns - April 2020 to Present");
plt.savefig("Images/TLTCumulativeReturns.png")

# %%
# Creating date variables to use in plot
from datetime import date, timedelta
days_after_xlim = (date.today()+timedelta(days=50)).isoformat()

days_after_stocks = (date.today()+timedelta(days=2)).isoformat()

days_after_btc = (date.today()+timedelta(days=1)).isoformat()

# %%
# Overlay of cumulative performances
ax = btc_profit.plot(figsize=(20,10), legend=True, title="Cumulative Returns - All Tickers - April 2020 to Present")
spy_profit.plot(ax=ax, legend=True)
gld_profit.plot(ax=ax, legend=True)
tlt_profit.plot(ax=ax, legend=True)
ax.text(days_after_stocks, tlt_annotation, f"${tlt_annotation:,}", size=12)
ax.text(days_after_stocks, gld_annotation, f"${gld_annotation:,}", size=12)
ax.text(days_after_stocks, spy_annotation, f"${spy_annotation:,}", size=12)
ax.text(days_after_btc, btc_annotation, f"${btc_annotation:,}", size=12)
ax.set(ylabel='Market Value of Principal Invested (USD)',
       xlabel=' ')
ax.set_xlim('2020-04', days_after_xlim)
plt.savefig("Images/OverlayCumulativeReturns.png");

# %%
# Plot performance in percentage terms and save to Images
(BTC_cumprod*100).plot(figsize=(20,10), legend=True, title="BTC Percent Returns - April 2020 to Present");
plt.savefig("Images/BTCPercentReturns.png")

# %%
# Plot performance in percentage terms and save to Images
(SPY_cumprod*100).plot(figsize=(20,10), legend=True, title="SPY Percent Returns - April 2020 to Present");
plt.savefig("Images/SPYPercentReturns.png")

# %%
# Plot performance in percentage terms and save to Images
(GLD_cumprod*100).plot(figsize=(20,10), legend=True, title="GLD Percent Returns - April 2020 to Present");
plt.savefig("Images/GLDPercentReturns.png")

# %%
# Plot performance in percentage terms and save to Images
(TLT_cumprod*100).plot(figsize=(20,10), legend=True, title="TLT Percent Returns - April 2020 to Present");
plt.savefig("Images/TLTPercentReturns.png")

# %%
# Creating date variables to use in plot
from datetime import date, timedelta
days_after_xlim_pct = (date.today()+timedelta(days=40)).isoformat()

days_after_stocks_pct = (date.today()+timedelta(days=4)).isoformat()

days_after_btc_pct = (date.today()+timedelta(days=2)).isoformat()

# %%
# Overlay of percentage returns 
with plt.style.context('seaborn-whitegrid'):
    ax = ((BTC_cumprod*100)-100).plot(figsize=(20,10), legend=True, title="Percentage Returns - All Tickers - April 2020 to Present")
    ((SPY_cumprod*100)-100).plot(ax=ax, legend=True)
    ((GLD_cumprod*100)-100).plot(ax=ax, legend=True)
    ((TLT_cumprod*100)-100).plot(ax=ax, legend=True)
    ax.text(days_after_stocks_pct, TLT_prod_annotation-100, f"{TLT_prod_annotation-100}%", size=14)
    ax.text(days_after_stocks_pct, GLD_prod_annotation-100, f"{GLD_prod_annotation-100}%", size=14)
    ax.text(days_after_stocks_pct, SPY_prod_annotation-100, f"{SPY_prod_annotation-100}%", size=14)
    ax.text(days_after_btc_pct, BTC_prod_annotation-100, f"{BTC_prod_annotation-100}%", size=14)
    ax.set(ylabel='Percentage Returns on Principal Invested (USD)',
           xlabel=' ')
    ax.set_xlim('2020-04', days_after_xlim_pct)
    plt.legend(loc=(.93,.8625))
    plt.savefig("Images/OverlayPercentageReturns.png");

# %%
# Rechecking info
btc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994 entries, 0 to 993
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       994 non-null    object
#  1   timestamp    994 non-null    object
#  2   open         994 non-null    float64
#  3   high         994 non-null    float64
#  4   low          994 non-null    float64
#  5   close        994 non-null    float64
#  6   volume       994 non-null    float64
#  7   trade_count  994 non-null    float64
#  8   vwap         994 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 70.0+ KB

# %%
# Shifting timestamp back to datetime to filter on month start dates
btc_df['timestamp'] = pd.to_datetime(btc_df['timestamp'])
btc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994 entries, 0 to 993
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       994 non-null    object
#  1   timestamp    994 non-null    datetime64[ns]
#  2   open         994 non-null    float64
#  3   high         994 non-null    float64
#  4   low          994 non-null    float64
#  5   close        994 non-null    float64
#  6   volume       994 non-null    float64
#  7   trade_count  994 non-null    float64
#  8   vwap         994 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 70.0+ KB

# %%
# Filtering for month start dates
btc_monthly = btc_df[btc_df['timestamp'].dt.is_month_start] 
btc_monthly
# Out:
#       symbol  timestamp     open      high       low     close       volume  \
# 5    BTC/USD 2020-05-01   8826.5   8834.00   8716.00   8816.50     0.300700
# 29   BTC/USD 2020-06-01   9568.5  10393.00   9515.00  10106.50     5.950700
# 59   BTC/USD 2020-07-01   9129.5   9270.00   9129.50   9240.50     5.467900
# 90   BTC/USD 2020-08-01  11619.5  12035.00  10594.50  11221.50     0.667400
# 116  BTC/USD 2020-09-01  11805.5  12005.50  11805.50  11847.50     0.404900
# 146  BTC/USD 2020-10-01  10821.0  10913.00  10477.00  10654.50     5.505900
# 177  BTC/USD 2020-11-01  13721.0  13842.50  13688.00  13688.00     1.499100
# 207  BTC/USD 2020-12-01  19469.5  19916.00  18222.00  18586.50    32.057500
# 238  BTC/USD 2021-01-01  29225.0  29631.00  28750.00  29631.00    25.076500
# 269  BTC/USD 2021-02-01  33787.0  34697.00  33145.00  33992.00   815.611700
# 297  BTC/USD 2021-03-01  46241.0  50224.00  45863.00  48749.00   266.388900
# 328  BTC/USD 2021-04-01  58934.0  60140.00  57957.00  59512.00   220.013800
# 358  BTC/USD 2021-05-01  58017.0  58449.00  56253.00  56962.00   451.689800
# 389  BTC/USD 2021-06-01  36740.0  37444.00  35536.00  36702.00   854.100000
# 419  BTC/USD 2021-07-01  34302.0  34486.00  32724.00  33103.00   631.628100
# 450  BTC/USD 2021-08-01  42117.0  42156.00  39265.00  39704.00   674.739700
# 481  BTC/USD 2021-09-01  47128.0  49910.00  47124.00  49420.00   970.770000
# 2021-03-01  0.434132
# 2021-04-01  0.220784
# 2021-05-01 -0.042849
# 2021-06-01 -0.355676
# 2021-07-01 -0.098060
# 2021-08-01  0.199408
# 2021-09-01  0.244711
# 2021-10-01 -0.037009
# 2021-11-01  0.291715
# 2021-12-01 -0.073966
# 2022-01-01 -0.173802
# 2022-02-01 -0.183169
# 2022-03-01  0.152741
# 2022-04-01  0.051325
# 2022-05-01 -0.163191
# 2022-06-01 -0.235826
# 2022-07-01 -0.355927
# 2022-08-01  0.192689
# 2022-09-01 -0.118534
# 2022-10-01 -0.041121
# 2022-11-01  0.061301
# 2022-12-01 -0.174473
# 2023-01-01 -0.017344

# %%
# Rechecking info
btc_chg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 33 entries, 2020-05-01 to 2023-01-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   close   32 non-null     float64
# dtypes: float64(1)
# memory usage: 528.0 bytes

# %%
# Convert index back to string to prep for plotting
btc_chg.index = btc_chg.index.strftime("%Y-%m-%d")
btc_chg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 2020-05-01 to 2023-01-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   close   32 non-null     float64
# dtypes: float64(1)
# memory usage: 528.0+ bytes

# %%
# Plot performance in month over month percentage change and save to Images
with plt.style.context('seaborn-whitegrid'):
    (btc_chg*100).plot(kind='bar', figsize=(20,10), legend=True, title="BTC Month Over Month % Returns - April 2020 to Present");
    plt.savefig("Images/BTCMonthlyPercentReturns.png")

# %%
# Prep SPY dataframe
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2118 entries, 0 to 2117
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       2118 non-null   object
#  1   timestamp    2118 non-null   object
#  2   open         2118 non-null   float64
#  3   high         2118 non-null   float64
#  4   low          2118 non-null   float64
#  5   close        2118 non-null   float64
#  6   volume       2118 non-null   float64
#  7   trade_count  2118 non-null   float64
#  8   vwap         2118 non-null   float64
# dtypes: float64(7), object(2)
# memory usage: 149.0+ KB

# %%
# Shifting timestamp back to datetime to filter on month start dates
stock_df['timestamp'] = pd.to_datetime(stock_df['timestamp'])
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2118 entries, 0 to 2117
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       2118 non-null   object
#  1   timestamp    2118 non-null   datetime64[ns]
#  2   open         2118 non-null   float64
#  3   high         2118 non-null   float64
#  4   low          2118 non-null   float64
#  5   close        2118 non-null   float64
#  6   volume       2118 non-null   float64
#  7   trade_count  2118 non-null   float64
#  8   vwap         2118 non-null   float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 149.0+ KB

# %%
stock_df
# Out:
#      symbol  timestamp    open     high       low    close      volume  \
# 0       GLD 2020-04-08  155.91  155.940  154.5900  154.650   7600804.0
# 1       GLD 2020-04-09  158.08  159.080  157.2100  158.580  18123039.0
# 2       GLD 2020-04-13  159.17  162.380  158.6250  161.410  20549213.0
# 3       GLD 2020-04-14  162.73  164.420  161.7800  162.660  17095086.0
# 4       GLD 2020-04-15  161.80  162.540  160.8061  162.000  12141890.0
# ...     ...        ...     ...      ...       ...      ...         ...
# 2113    TLT 2023-01-20  106.96  107.240  106.1100  106.200  22754067.0
# 2114    TLT 2023-01-23  105.57  106.200  105.4900  105.700  12962623.0
# 2115    TLT 2023-01-24  106.12  107.450  105.3900  107.220  16418921.0
# 2116    TLT 2023-01-25  107.37  107.905  106.6400  107.480  12193402.0
# 2022-08-01    TLT  118.250  120.1000  118.080  120.04  17972699.0
# 2022-09-01    TLT  109.870  110.2500  108.940  109.60  22490448.0
# 2022-10-03    TLT  103.850  104.6800  103.150  103.83  27892138.0
# 2022-11-01    TLT   97.380   97.4200   96.210   96.77  17585088.0
# 2022-12-01    TLT  103.150  105.8100  103.100  105.76  53156786.0
#
#             trade_count        vwap
# timestamp
# 2020-05-01      52918.0  167.362331
# 2020-06-01      54793.0  162.363115
# 2020-07-01      66576.0  163.014043
# 2020-08-03      61181.0  169.514329
# 2020-09-01      58232.0  163.138871
# 2020-10-01      62953.0  163.194508
# 2020-11-02      57471.0  158.700148
# 2020-12-01      73359.0  157.524279
# 2021-01-01      66776.0  157.536581
# 2021-02-01      41773.0  151.926223
# 2021-03-01     131299.0  140.676610
# 2021-04-01      66587.0  137.128607
# 2021-05-03      84727.0  138.785396
# 2021-06-01      61981.0  137.875244
# 2021-07-01      55429.0  143.845345
# 2021-08-02      93872.0  150.455494
# 2021-09-01      62840.0  148.892889
# 2021-10-01     120052.0  144.946760
# 2021-11-01     102768.0  146.233070
# 2021-12-01     159674.0  151.363718
# 2022-01-03     132357.0  145.398962
# 2022-02-01      97271.0  141.680747
# 2022-03-01     227202.0  141.322926
# 2022-04-01     149421.0  131.842770
# 2022-05-02     165127.0  117.383631
# 2022-06-01      89438.0  116.259375
# 2022-07-01     138117.0  116.113939
# 2022-08-01     106497.0  119.478759
# 2022-09-01     131508.0  109.661551
# 2022-10-03     138135.0  103.804973
# 2022-11-01     117591.0   96.698772
# 2022-12-01     215289.0  104.856665

# %%
# Grabbing subset of SPY timestamp and closing prices 
spy_close = spy_iloc['close']
spy_close

# Calculating pct change
spy_pct = spy_close.pct_change()

# Convert index back to string to prep for plotting
spy_pct.index = spy_pct.index.strftime("%Y-%m-%d")

# Plot performance in month over month percentage change and save to Images
with plt.style.context('seaborn-whitegrid'):
    (spy_pct*100).plot(kind='bar', figsize=(20,10), legend=True, title="SPY Month Over Month % Returns - May 2020 to Present");
    plt.savefig("Images/SPYMonthlyPercentReturns.png")

# %%
# Grabbing subset of GLD timestamp and closing prices 
gld_close = gld_iloc['close']

# Calculating pct change
gld_pct = gld_close.pct_change()

# Convert index back to string to prep for plotting
gld_pct.index = gld_pct.index.strftime("%Y-%m-%d")

# Plot performance in month over month percentage change and save to Images
with plt.style.context('seaborn-whitegrid'):
    (gld_pct*100).plot(kind='bar', figsize=(20,10), legend=True, title="GLD Month Over Month % Returns - May 2020 to Present");
    plt.savefig("Images/GLDMonthlyPercentReturns.png")

# %%
# Grabbing subset of TLT timestamp and closing prices 
tlt_close = tlt_iloc['close']

# Calculating pct change
tlt_pct = tlt_close.pct_change()

# Convert index back to string to prep for plotting
tlt_pct.index = tlt_pct.index.strftime("%Y-%m-%d")

# Plot performance in month over month percentage change and save to Images
with plt.style.context('seaborn-whitegrid'):
    (tlt_pct*100).plot(kind='bar', figsize=(20,10), legend=True, title="TLT Month Over Month % Returns - May 2020 to Present");
    plt.savefig("Images/TLTMonthlyPercentReturns.png")

# %%
# Overlay of percentage returns 
with plt.style.context('seaborn-whitegrid'):
    ax = (btc_chg*100).plot(kind='bar', figsize=(20,10), legend=True, title="Month Over Month % Returns - All Tickers - May 2020 to Present");
    (spy_pct*100).plot(ax=ax, legend=True)
    (gld_pct*100).plot(ax=ax, legend=True)
    (tlt_pct*100).plot(ax=ax, legend=True)

    ax.set(ylabel='Percentage Returns on Principal Invested (USD)',
           xlabel=' ')
#     ax.set_xlim('2020-04', days_after_xlim_pct)
#     plt.legend(loc=(.93,.8625))
    plt.savefig("Images/OverlayMoMPercentageReturns.png");

# %%
# Month end dates plus 5/29
month_end_df = stock_df.loc[(stock_df.timestamp.dt.is_month_end) | (stock_df.timestamp.dt.day == 15), :]
month_end_df
# Out:
#      symbol  timestamp     open      high       low   close      volume  \
# 4       GLD 2020-04-15  161.800  162.5400  160.8061  162.00  12141890.0
# 15      GLD 2020-04-30  160.220  160.8200  158.1300  158.80  13633483.0
# 26      GLD 2020-05-15  164.020  164.8000  163.0800  163.93  13918816.0
# 46      GLD 2020-06-15  160.520  162.5600  160.1600  162.33   8538826.0
# 57      GLD 2020-06-30  166.310  167.9906  166.1850  167.37  12762597.0
# ...     ...        ...      ...       ...       ...     ...         ...
# 2037    TLT 2022-09-30  104.270  104.8600  102.2250  102.45  26484990.0
# 2058    TLT 2022-10-31   96.360   96.6200   95.0300   96.11  23956265.0
# 2069    TLT 2022-11-15   98.250   99.3000   98.1100   99.23  26585624.0
# 2079    TLT 2022-11-30  101.615  102.7300  101.3700  102.73  21594217.0
# 2090    TLT 2022-12-15  108.390  109.1200  108.1600  108.32  20255470.0
#
#       trade_count        vwap
# 4         95518.0  161.749049
# 15       107884.0  159.269773
# 26       103072.0  164.068763
# 46        60744.0  161.585502
# 57        84161.0  167.268997
# ...           ...         ...
# 2037     176869.0  103.216833
# 2058     139205.0   95.885319
# 2069     155459.0   98.868782
# 2079     143566.0  102.184996
# 2090     112012.0  108.578492
#
# [141 rows x 9 columns]

# %%
month_end_df.tail(33)
# Out:
#      symbol  timestamp      open     high      low   close      volume  \
# 1607    TLT 2021-01-15  152.1850  152.360  151.470  151.82  11624672.0
# 1646    TLT 2021-03-15  136.4900  137.090  136.410  136.86  11366662.0
# 1658    TLT 2021-03-31  136.3400  136.590  134.980  135.45  19292467.0
# 1668    TLT 2021-04-15  139.4900  140.980  139.455  140.32  21420799.0
# 1679    TLT 2021-04-30  138.5070  138.730  137.980  138.64  15684149.0
# 1710    TLT 2021-06-15  140.8000  141.090  140.480  141.05  18177787.0
# 1721    TLT 2021-06-30  144.2500  144.930  144.070  144.35  15707427.0
# 1731    TLT 2021-07-15  147.9500  148.600  147.030  148.49  18454932.0
# 1764    TLT 2021-08-31  149.6700  150.090  148.500  148.83  15253807.0
# 1774    TLT 2021-09-15  151.2100  151.250  149.930  150.58  11936274.0
# 1785    TLT 2021-09-30  144.1000  144.515  143.650  144.32  22513240.0
# 1796    TLT 2021-10-15  145.0000  145.140  144.470  145.03  11794328.0
# 1817    TLT 2021-11-15  146.8900  146.960  145.220  145.48  15229963.0
